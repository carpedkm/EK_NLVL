# %%
pth = '/ektnlvl/data/charades/annotations/charades_gt_bartsumm__result_mnli_nb4_lp2.0_maxl50_minl10_ng3.txt'

# %%
with open(pth, 'r') as f:
    tmp = f.readlines()

# %%
tmp
# Out:
# ['004QE 14.2 22.5##a woman is brushing her teeth in a bathroom with a. a woman taking a picture of herself in a mirror. a Woman is taking a selfie in a taking a photo of a picture. a a woman is holding a video game\n',
#  '00HFP 13.6 21.9##a man standing in a room with a laptop computer. a woman standing on the floor in a bedroom with a a. a person standing on a red floor next to a toto. a a person is standing on either side of a\n',
#  '00MFE 14.7 20.54##a man standing in a bathroom with a toothbrush in a mirror. a man is looking at his reflection in front of a mirror rather than brushing his teeth. a woman holding a on the other hand is a different situation. a\n',
#  "00N38 14.3 20.8##a man standing in a doorway with a bag. a man standing, no, wait, that's not a man, a man holding a surfboard. a nope, a nay, a sir, a sailor, nay\n",
# ...

# %%
total = ''
for line_ in tmp:
    sent = line_.split('##')[1].strip().split('.')[0] + '.'
    id_and_val = line_.split('##')[0].strip()
    to_wr = id_and_val + '##' + sent+ '\n'
    total = total + to_wr
